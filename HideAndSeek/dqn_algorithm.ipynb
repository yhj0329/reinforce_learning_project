# %%
import gym
import numpy as np
import tensorflow as tf
from tensorflow.contrib.layers import flatten, conv2d, fully_connected
from collections import deque, Counter
import random
from datetime import datetime
from IPython import display
import matplotlib.pyplot as plt
import time
from hide_and_seek_3thief import HideAndSeekEnv
# %matplotlib inline
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 환경 설정
env = HideAndSeekEnv()
n_outputs = env.action_space.n
env.render()
# Out:
# o - - - - - - - - - - - - - - - - - o
# | P |       |           |           |
# |           | - |   |   | - | - | 3 |
# |   |               |   |         2 |
# | - | 2                     | - |   |
# |       |   |                       |
# |   |                       | - |   |
# |   |                       |       |
# |   | - | - | - |           | - |   |
# |                               | - |
# o - - - - - - - - - - - - - - - - - o

# %%
# Q 네트워크를 구축하기 위해 q_network라는 함수를 정의
# Q 네트워크를 입력하고 해당 상태의 모든 작업에 대한 Q 값을 얻는다.
# fully connected layer가 이어지는 동일한 패딩을 가진 3개의 convolutional layers로 Q 네트워크를 구축
tf.reset_default_graph()

def q_network(X, name_scope):
    #layers 초기화
    initializer = tf.contrib.layers.variance_scaling_initializer()
    
    with tf.variable_scope(name_scope) as scope:
        #convolutional layers 초기화
        layer_1 = conv2d(X, num_outputs=32, kernel_size=(5,5), stride=4, padding="SAME", weights_initializer=initializer)
        tf.summary.histogram('layer_1',layer_1)
        
        layer_2 = conv2d(layer_1, num_outputs=64, kernel_size=(3,3), stride=2, padding="SAME", weights_initializer=initializer)
        tf.summary.histogram('layer_2',layer_2)
        
        layer_3 = conv2d(layer_2, num_outputs=64, kernel_size=(3,3), stride=1, padding="SAME", weights_initializer=initializer)
        tf.summary.histogram('layer_3',layer_3)
        
        # fully connected layer에 공급하기 전에 layer_3의 결과를 평탄화
        flat = flatten(layer_3)
        
        fc = fully_connected(flat, num_outputs=128, weights_initializer=initializer)
        tf.summary.histogram('fc',fc)
        
        output = fully_connected(fc, num_outputs=n_outputs, activation_fn=None, weights_initializer=initializer)
        tf.summary.histogram('output',output)
        
        #vars는 가중치와 같은 네트워크 매개변수를 저장
        vars = {v.name[len(scope.name):]: v for v in tf.get_collection(key=tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)}
        return vars, output

# %%
# 엡실론 그리디 정책을 수행하기 위해 epsilon_greedy라는 함수를 정의
# 영원히 탐색하고 싶지 않기 때문에 엡실론의 가치가 시간이 지남에 따라 쇠퇴하는 쇠퇴 엡실론 탐욕 정책을 사용
# 즉, 시간이 지남에 따라 우리 정책은 좋은 행동만 이용할 것입니다.
eps_min=0.05
eps_max=0.5
eps_decay_steps = 500000

def epsilon_greedy(action, step):
    p = np.random.random(1).squeeze()
    epsilon = max(eps_min, eps_max - (eps_max-eps_min) * step/eps_decay_steps)
    if np.random.rand() < epsilon:
        return np.random.randint(n_outputs)
    else:
        return action

# %%
# 경험을 보유하는 50000의 경험 버퍼를 초기화
# 에이전트의 모든 경험, 즉 (상태, 행동, 보상)을 경험 버퍼에 저장하고 네트워크 훈련을 위해 이 경험의 미니배치에서 샘플링
buffer_len = 20000
exp_buffer = deque(maxlen=buffer_len)

# 메모리에서 경험을 샘플링하기 위해 sampled_memories라는 함수를 정의
# 배치 크기는 메모리에서 샘플링된 경험의 수이다.
def sample_memories(batch_size):
    perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
    mem = np.array(exp_buffer)[perm_batch]
    return mem[:,0],mem[:,1],mem[:,2],mem[:,3],mem[:,4]

# %%
# 하이퍼파라미터 정의
num_episodes = 1000
batch_size = 48
input_shape = (None, 11, 19, 1)
learning_rate = 0.001
X_shape = (None, 11, 19, 1)
discount_factor = 0.97

global_step = 0
copy_steps = 100
steps_train = 4
start_steps = 2000

# %%
logdir = 'hideandseek_logs'
tf.reset_default_graph()

# 입력에 대한 게임 상태를 정의
X = tf.placeholder(tf.float32, shape=X_shape)

# 교육을 토글하기 위해 in_training_model이라는 부울을 정의
in_training_mode = tf.placeholder(tf.bool)

# %%
# 기본 대상 Q 네트워크를 구축
# 입력 X를 취하고 상태의 모든 작업에 대해 Q 값을 생성하는 Q 네트워크를 구축
mainQ, mainQ_outputs = q_network(X, 'mainQ')

# 목표 Q 네트워크를 구축
targetQ, targetQ_outputs = q_network(X, 'targetQ')

# %%
# 행동 값에 대한 자리 표시자 정의
X_action = tf.placeholder(tf.int32, shape=(None,))
Q_action = tf.reduce_sum(targetQ_outputs * tf.one_hot(X_action, n_outputs), axis=-1,keep_dims=True)

# %%
# 기본 Q 네트워크 매개변수를 대상 Q 네트워크에 복사
copy_op = [tf.assign(main_name, targetQ[var_name]) for var_name, main_name in mainQ.items()]
copy_target_to_main = tf.group(*copy_op)

# %%
# gradient descent optimizer를 사용하여 손실 계산 및 최적화

# 행동에 대한 자리 표시자를 정의
y = tf.placeholder(tf.float32, shape=(None,1))

# 실제 값과 예측 값의 차이인 손실을 계산
loss = tf.reduce_mean(tf.square(y - Q_action))

# loss을 최소화하기 위해 adam optimizer를 사용
optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()

loss_summary = tf.summary.scalar('Loss', loss)
merge_summary = tf.summary.merge_all()
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

# %%
# tensorflow와 그 안의 모델을 실행
with tf.Session() as sess:
    init.run()
    
    # 로그를 기록할 파일 열기
    log_file = "hideandseek_log.txt"
    
    #에피소드
    for i in range(num_episodes):
        done = False
        obs = env.reset()
        epoch = 0
        episodic_reward = 0
        actions_counter = Counter()
        episodic_loss = []
        
        #상태가 최종 상태가 아닌 동안
        while not done:
            # 전처리된 게임 화면 가져오기
            obs = env.render('dqn')
            
            # 게임 화면을 피드하고 각 작업에 대한 Q 값을 가져오기
            actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode: False})
            
            # 행동 가져오기
            action = np.argmax(actions, axis =-1)
            actions_counter[str(action)] += 1
            
            #엡실론 그리디 정책을 사용하여 행동 선택
            action = epsilon_greedy(action, global_step)
            
            #행동을 수행하고 다음 상태인 next_obs로 이동하여 보상을 받는다.
            next_obs, reward, done, _ = env.step(action)
            
            #이 전환을 재생 버퍼에 경험으로 저장
            exp_buffer.append([obs, action, next_obs, reward, done])
            
            #특정 단계 후에 경험 버퍼의 샘플로 Q 네트워크를 훈련
            if global_step % steps_train == 0 and global_step > start_steps:
                # 샘플 경험
                o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)
                
                # 상태
                o_obs = [x for x in o_obs]
                
                # 다음 상태
                o_next_obs = [x for x in o_next_obs]
                
                # 다음 행동
                next_act = mainQ_outputs.eval(feed_dict={X:o_next_obs, in_training_mode:False})
                
                # 보상
                y_batch = o_rew + discount_factor * np.max(next_act, axis=-1) * (1-o_done)
                
                # 모든 요약을 병합하고 파일에 쓰기
                mrg_summary = merge_summary.eval(feed_dict={X: o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:False})
                file_writer.add_summary(mrg_summary, global_step)
                
                # 네트워크 훈련 및 loss 계산
                train_loss, _ = sess.run([loss, training_op], feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode: True})
                episodic_loss.append(train_loss)
                
            # 일정 간격 후에 주요 Q 네트워크 가중치를 대상 Q 네트워크에 복사
            if (global_step+1)%copy_steps == 0 and global_step > start_steps:
                copy_target_to_main.run()
                    
            epoch += 1
            global_step += 1
            episodic_reward += reward
            
        # 파일에 로그 기록
        with open(log_file, "a") as file:
            file.write("Epoch: " + str(epoch) + ", Reward: " + str(episodic_reward))
            file.write(", Loss: " + str(np.mean(episodic_loss)))
            file.write(", Actions: " + str(actions_counter) + "\n")
        
        # 정보 출력
        print('Epoch', epoch, 'Reward', episodic_reward)
        
    # 저장 객체 생성
    saver = tf.train.Saver()
    
    # 모델 저장
    saver.save(sess, './model', global_step=global_step)
# Out:
# Epoch 2159 Reward -15590
# Epoch 644 Reward -3950
# Epoch 1431 Reward -7257
# Epoch 2535 Reward -13950
# Epoch 1039 Reward -4588
# Epoch 720 Reward -2307
# Epoch 1009 Reward -3244
# Epoch 1467 Reward -5313
# Epoch 1749 Reward -5829
# Epoch 1063 Reward -3055
# Epoch 591 Reward -1701
# Epoch 566 Reward -1631
# Epoch 2884 Reward -9259
# Epoch 1214 Reward -3513
# Epoch 911 Reward -3281
# Epoch 803 Reward -2723
# Epoch 149 Reward -116
# Epoch 355 Reward -889
# Epoch 676 Reward -1813
# Epoch 273 Reward -645
# Epoch 228 Reward -645
# Epoch 591 Reward -1440
# Epoch 84 Reward -33
# Epoch 660 Reward -1986
# Epoch 1254 Reward -4290
# Epoch 334 Reward -661
# Epoch 2473 Reward -7714
# Epoch 801 Reward -2010
# Epoch 2190 Reward -6495
# Epoch 636 Reward -1944
# Epoch 738 Reward -1902
# Epoch 424 Reward -1093
# Epoch 1859 Reward -5903
# Epoch 606 Reward -1807
# Epoch 2227 Reward -6838
# Epoch 613 Reward -1354
# Epoch 1234 Reward -3028
# Epoch 1427 Reward -3653
# Epoch 602 Reward -1352
# Epoch 432 Reward -1056
# Epoch 2130 Reward -6057
# Epoch 327 Reward -493
# Epoch 3339 Reward -10506
# Epoch 1150 Reward -3124
# Epoch 448 Reward -1189
# Epoch 280 Reward -481
# Epoch 720 Reward -1812
# Epoch 1275 Reward -3366
# Epoch 114 Reward -135
# Epoch 511 Reward -1252
# Epoch 777 Reward -1546
# Epoch 1484 Reward -3215
# Epoch 889 Reward -2728
# Epoch 663 Reward -1368
# Epoch 97 Reward 89
# Epoch 941 Reward -2060
# Epoch 376 Reward -865
# Epoch 486 Reward -1434
# Epoch 301 Reward -835
# Epoch 299 Reward -401
# Epoch 703 Reward -1948
# Epoch 304 Reward -757
# Epoch 511 Reward -955
# Epoch 619 Reward -1693
# Epoch 537 Reward -1422
# Epoch 213 Reward -540
# Epoch 632 Reward -1454
# Epoch 754 Reward -1765
# Epoch 642 Reward -1545
# Epoch 409 Reward -674
# Epoch 748 Reward -1813
# Epoch 170 Reward -353
# Epoch 570 Reward -1248
# Epoch 615 Reward -1527
# Epoch 376 Reward -676
# Epoch 961 Reward -2359
# Epoch 438 Reward -981
# Epoch 167 Reward -179
# Epoch 248 Reward -440
# Epoch 969 Reward -2520
# Epoch 132 Reward -144
# Epoch 653 Reward -1637
# Epoch 429 Reward -1170
# Epoch 483 Reward -1044
# Epoch 806 Reward -2501
# Epoch 39 Reward 236
# Epoch 666 Reward -1542
# Epoch 448 Reward -730
# Epoch 555 Reward -2745
# Epoch 431 Reward -1073
# Epoch 615 Reward -1104
# Epoch 509 Reward -1592
# Epoch 985 Reward -2230
# Epoch 205 Reward -496
# Epoch 442 Reward -724
# Epoch 362 Reward -1202
# Epoch 800 Reward -2027
# Epoch 620 Reward -2027
# Epoch 522 Reward -1146
# Epoch 1071 Reward -2163
# Epoch 589 Reward -1159
# Epoch 780 Reward -1845
# Epoch 977 Reward -2555
# Epoch 908 Reward -2684
# Epoch 1399 Reward -3454
# Epoch 822 Reward -1806
# Epoch 493 Reward -1045
# Epoch 1784 Reward -5090
# Epoch 830 Reward -2309
# Epoch 1103 Reward -2366
# Epoch 671 Reward -1430
# Epoch 656 Reward -1631
# Epoch 1079 Reward -2999
# Epoch 809 Reward -2045
# Epoch 843 Reward -2043
# Epoch 775 Reward -2146
# Epoch 434 Reward -662
# Epoch 770 Reward -1583
# Epoch 409 Reward -710
# Epoch 1365 Reward -4176
# Epoch 362 Reward -608
# Epoch 358 Reward -640
# Epoch 741 Reward -2112
# Epoch 123 Reward -18
# Epoch 697 Reward -1726
# Epoch 858 Reward -2715
# Epoch 225 Reward -543
# Epoch 426 Reward -951
# Epoch 1866 Reward -4488
# Epoch 249 Reward -712
# Epoch 698 Reward -2213
# Epoch 120 Reward -132
# Epoch 54 Reward 177
# Epoch 993 Reward -2706
# Epoch 882 Reward -2181
# Epoch 518 Reward -1628
# Epoch 305 Reward -587
# Epoch 1021 Reward -3067
# Epoch 542 Reward -1292
# Epoch 715 Reward -1636
# Epoch 282 Reward -843
# Epoch 1171 Reward -3037
# Epoch 420 Reward -1467
# Epoch 462 Reward -969
# Epoch 191 Reward -194
# Epoch 364 Reward -1078
# Epoch 244 Reward -175
# Epoch 258 Reward -486
# Epoch 602 Reward -1262
# Epoch 1285 Reward -3394
# Epoch 130 Reward -52
# Epoch 587 Reward -1706
# Epoch 399 Reward -906
# Epoch 581 Reward -1313
# Epoch 152 Reward -344
# Epoch 183 Reward -537
# Epoch 448 Reward -1262
# Epoch 398 Reward -626
# Epoch 214 Reward -334
# Epoch 699 Reward -1611
# Epoch 589 Reward -1672
# Epoch 538 Reward -1495
# Epoch 984 Reward -3237
# Epoch 393 Reward -1188
# Epoch 161 Reward -587
# Epoch 403 Reward -1594
# Epoch 551 Reward -1688
# Epoch 1121 Reward -4013
# Epoch 178 Reward -307
# Epoch 318 Reward -933
# Epoch 461 Reward -1562
# Epoch 987 Reward -2079
# Epoch 558 Reward -894
# Epoch 222 Reward -675
# Epoch 1269 Reward -3225
# Epoch 378 Reward -1470
# Epoch 229 Reward -484
# Epoch 238 Reward -655
# Epoch 711 Reward -2406
# Epoch 176 Reward -422
# Epoch 394 Reward -964
# Epoch 265 Reward -394
# Epoch 1268 Reward -3206
# Epoch 796 Reward -1978
# Epoch 306 Reward -354
# Epoch 334 Reward -598
# Epoch 230 Reward -260
# Epoch 259 Reward -407
# Epoch 227 Reward -348
# Epoch 1295 Reward -3764
# Epoch 768 Reward -1752
# Epoch 207 Reward -453
# Epoch 367 Reward -451
# Epoch 697 Reward -1591
# Epoch 723 Reward -1554
# Epoch 640 Reward -1435
# Epoch 768 Reward -2274
# Epoch 421 Reward -1234
# Epoch 791 Reward -2135
# Epoch 424 Reward -967
# Epoch 964 Reward -3631
# Epoch 519 Reward -927
# Epoch 470 Reward -735
# Epoch 849 Reward -2040
# Epoch 123 Reward 18
# Epoch 1202 Reward -3194
# Epoch 952 Reward -2350
# Epoch 169 Reward -325
# Epoch 122 Reward 1
# Epoch 288 Reward -462
# Epoch 136 Reward -148
# Epoch 287 Reward -308
# Epoch 547 Reward -1270
# Epoch 425 Reward -1166
# Epoch 186 Reward -792
# Epoch 490 Reward -988
# Epoch 507 Reward -1599
# Epoch 1020 Reward -3588
# Epoch 1693 Reward -4693
# Epoch 377 Reward -1343
# Epoch 240 Reward -819
# Epoch 364 Reward -781
# Epoch 1463 Reward -4355
# Epoch 499 Reward -1195
# Epoch 485 Reward -1622
# Epoch 2330 Reward -6185
# Epoch 179 Reward -345
# Epoch 92 Reward -23
# Epoch 1341 Reward -3603
# Epoch 1709 Reward -4547
# Epoch 659 Reward -1544
# Epoch 1064 Reward -2174
# Epoch 360 Reward -561
# Epoch 787 Reward -1906
# Epoch 472 Reward -898
# Epoch 231 Reward -234
# Epoch 2990 Reward -7304
# Epoch 959 Reward -1970
# Epoch 167 Reward -125
# Epoch 369 Reward -669
# Epoch 482 Reward -1511
# Epoch 190 Reward -301
# Epoch 165 Reward -303
# Epoch 174 Reward -429
# Epoch 166 Reward -466
# Epoch 1736 Reward -4385
# Epoch 842 Reward -1880
# Epoch 1268 Reward -2891
# Epoch 475 Reward -1594
# Epoch 842 Reward -2321
# Epoch 314 Reward -569
# Epoch 246 Reward -267
# Epoch 1102 Reward -2491
# Epoch 256 Reward -961
# Epoch 299 Reward -644
# Epoch 591 Reward -1044
# Epoch 403 Reward -649
# Epoch 277 Reward -775
# Epoch 211 Reward -673
# Epoch 223 Reward -631
# Epoch 469 Reward -1732
# Epoch 677 Reward -1211
# Epoch 140 Reward -251
# Epoch 466 Reward -1045
# Epoch 427 Reward -728
# Epoch 607 Reward -1231
# Epoch 451 Reward -1606
# Epoch 2373 Reward -5994
# Epoch 530 Reward -1451
# Epoch 508 Reward -1069
# Epoch 1100 Reward -2642
# Epoch 202 Reward -799
# Epoch 355 Reward -376
# Epoch 223 Reward -82
# Epoch 160 Reward -64
# Epoch 392 Reward -629
# Epoch 308 Reward -446
# Epoch 260 Reward -218
# Epoch 547 Reward -1279
# Epoch 457 Reward -1018
# Epoch 430 Reward -1162
# Epoch 509 Reward -1277
# Epoch 622 Reward -1345
# Epoch 1015 Reward -3016
# Epoch 462 Reward -1446
# Epoch 615 Reward -1473
# Epoch 72 Reward -3
# Epoch 411 Reward -1404
# Epoch 612 Reward -1155
# Epoch 448 Reward -694
# Epoch 713 Reward -1076
# Epoch 258 Reward -252
# Epoch 830 Reward -1652
# Epoch 356 Reward -539
# Epoch 1000 Reward -2425
# Epoch 91 Reward 76
# Epoch 722 Reward -1643
# Epoch 559 Reward -1075
# Epoch 251 Reward -299
# Epoch 254 Reward -338
# Epoch 1520 Reward -3170
# Epoch 139 Reward -79
# Epoch 513 Reward -1848
# Epoch 869 Reward -2447
# Epoch 456 Reward -1296
# Epoch 1585 Reward -4909
# Epoch 549 Reward -1030
# Epoch 913 Reward -1474
# Epoch 231 Reward -234
# Epoch 932 Reward -1907
# Epoch 1483 Reward -3898
# Epoch 1022 Reward -3968
# Epoch 381 Reward -1032
# Epoch 4245 Reward -8982
# Epoch 388 Reward -1570
# Epoch 1899 Reward -4224
# Epoch 585 Reward -1398
# Epoch 381 Reward -628
# Epoch 775 Reward -1606
# Epoch 676 Reward -1372
# Epoch 681 Reward -1404
# Epoch 544 Reward -808
# Epoch 336 Reward -762
# Epoch 1273 Reward -3166
# Epoch 416 Reward -743
# Epoch 576 Reward -1326
# Epoch 153 Reward -93
# Epoch 468 Reward -1452
# Epoch 558 Reward -1425
# Epoch 973 Reward -3010
# Epoch 1242 Reward -3630
# Epoch 196 Reward -55
# Epoch 1343 Reward -2561
# Epoch 408 Reward -538
# Epoch 1213 Reward -2269
# Epoch 258 Reward -486
# Epoch 950 Reward -1637
# Epoch 22 Reward 236
# Epoch 643 Reward -1051
# Epoch 1796 Reward -4067
# Epoch 486 Reward -939
# Epoch 195 Reward -324
# Epoch 515 Reward -1112
# Epoch 1324 Reward -3172
# Epoch 361 Reward -886
# Epoch 339 Reward -1215
# Epoch 388 Reward -616
# Epoch 847 Reward -1435
# Epoch 343 Reward -697
# Epoch 1499 Reward -2897
# Epoch 656 Reward -1172
# Epoch 599 Reward -1682
# Epoch 182 Reward -149
# Epoch 67 Reward 127
# Epoch 582 Reward -1521
# Epoch 648 Reward -1803
# Epoch 223 Reward -343
# Epoch 258 Reward -351
# Epoch 599 Reward -1403
# Epoch 348 Reward -864
# Epoch 422 Reward -983
# Epoch 351 Reward -588
# Epoch 48 Reward 164
# Epoch 97 Reward -46
# Epoch 278 Reward -524
# Epoch 260 Reward -191
# Epoch 643 Reward -1195
# Epoch 144 Reward -318
# Epoch 148 Reward -88
# Epoch 657 Reward -2406
# Epoch 961 Reward -1900
# Epoch 857 Reward -3344
# Epoch 172 Reward -391
# Epoch 66 Reward 191
# Epoch 534 Reward -1374
# Epoch 379 Reward -1219
# Epoch 1269 Reward -4530
# Epoch 147 Reward -141
# Epoch 278 Reward -632
# Epoch 373 Reward -988
# Epoch 140 Reward -143
# Epoch 655 Reward -1198
# Epoch 416 Reward -1139
# Epoch 314 Reward -543
# Epoch 220 Reward -115
# Epoch 563 Reward -953
# Epoch 296 Reward -344
# Epoch 394 Reward -586
# Epoch 329 Reward -494
# Epoch 545 Reward -899
# Epoch 1010 Reward -2588
# Epoch 1327 Reward -3616
# Epoch 667 Reward -1858
# Epoch 232 Reward -694
# Epoch 1683 Reward -3945
# Epoch 171 Reward -444
# Epoch 190 Reward -373
# Epoch 489 Reward -888
# Epoch 217 Reward -409
# Epoch 820 Reward -2281
# Epoch 258 Reward -315
# Epoch 521 Reward -911
# Epoch 453 Reward -1671
# Epoch 116 Reward -65
# Epoch 1272 Reward -2814
# Epoch 708 Reward -2025
# Epoch 231 Reward -198
# Epoch 263 Reward -482
# Epoch 267 Reward -378
# Epoch 485 Reward -713
# Epoch 122 Reward 28
# Epoch 606 Reward -942
# Epoch 608 Reward -1709
# Epoch 374 Reward -872
# Epoch 97 Reward -118
# Epoch 132 Reward 81
# Epoch 323 Reward -758
# Epoch 393 Reward -1044
# Epoch 364 Reward -655
# Epoch 563 Reward -1466
# Epoch 575 Reward -1370
# Epoch 624 Reward -1671
# Epoch 699 Reward -1368
# Epoch 481 Reward -1573
# Epoch 221 Reward -206
# Epoch 391 Reward -1177
# Epoch 101 Reward -131
# Epoch 347 Reward -404
# Epoch 1356 Reward -4095
# Epoch 220 Reward -709
# Epoch 248 Reward -773
# Epoch 1314 Reward -3315
# Epoch 358 Reward -1009
# Epoch 908 Reward -2702
# Epoch 347 Reward -683
# Epoch 1160 Reward -3143
# Epoch 569 Reward -950
# Epoch 274 Reward -340
# Epoch 553 Reward -907
# Epoch 282 Reward -402
# Epoch 898 Reward -2044
# Epoch 167 Reward -332
# Epoch 230 Reward -269
# Epoch 801 Reward -1704
# Epoch 783 Reward -1569
# Epoch 443 Reward -905
# Epoch 382 Reward -1069
# Epoch 134 Reward -20
# Epoch 131 Reward -62
# Epoch 1053 Reward -2604
# Epoch 131 Reward -89
# Epoch 78 Reward 72
# Epoch 870 Reward -1827
# Epoch 767 Reward -2237
# Epoch 317 Reward -563
# Epoch 271 Reward -643
# Epoch 133 Reward -172
# Epoch 226 Reward -670
# Epoch 78 Reward 107
# Epoch 249 Reward -522
# Epoch 553 Reward -862
# Epoch 208 Reward -337
# Epoch 279 Reward -912
# Epoch 356 Reward -1025
# Epoch 309 Reward -483
# Epoch 170 Reward -353
# Epoch 264 Reward -609
# Epoch 194 Reward -251
# Epoch 338 Reward -449
# Epoch 582 Reward -1539
# Epoch 1349 Reward -3035
# Epoch 574 Reward -1630
# Epoch 225 Reward -570
# Epoch 786 Reward -1509
# Epoch 478 Reward -1453
# Epoch 140 Reward -224
# Epoch 790 Reward -1675
# Epoch 458 Reward -812
# Epoch 690 Reward -1710
# Epoch 357 Reward -720
# Epoch 502 Reward -713
# Epoch 335 Reward -347
# Epoch 144 Reward -345
# Epoch 331 Reward -658
# Epoch 38 Reward 67
# Epoch 688 Reward -1969
# Epoch 545 Reward -1646
# Epoch 674 Reward -2666
# Epoch 785 Reward -1922
# Epoch 495 Reward -1137
# Epoch 682 Reward -1873
# Epoch 1810 Reward -4315
# Epoch 515 Reward -2237
# Epoch 134 Reward -254
# Epoch 420 Reward -846
# Epoch 477 Reward -2505
# Epoch 261 Reward -381
# Epoch 639 Reward -1227
# Epoch 202 Reward -250
# Epoch 996 Reward -1737
# Epoch 858 Reward -1644
# Epoch 446 Reward -431
# Epoch 290 Reward -689
# Epoch 518 Reward -1511
# Epoch 1150 Reward -3439
# Epoch 340 Reward -739
# Epoch 517 Reward -745
# Epoch 171 Reward -201
# Epoch 291 Reward -312
# Epoch 208 Reward -175
# Epoch 630 Reward -1056
# Epoch 231 Reward -288
# Epoch 280 Reward -463
# Epoch 388 Reward -661
# Epoch 974 Reward -1778
# Epoch 2882 Reward -5891
# Epoch 561 Reward -1266
# Epoch 1331 Reward -3269
# Epoch 183 Reward -339
# Epoch 135 Reward -327
# Epoch 1792 Reward -3685
# Epoch 360 Reward -1479
# Epoch 2205 Reward -4251
# Epoch 1801 Reward -3793
# Epoch 1947 Reward -3147
# Epoch 800 Reward -1127
# Epoch 773 Reward -1640
# Epoch 1734 Reward -4383
# Epoch 836 Reward -1352
# Epoch 1519 Reward -3421
# Epoch 1446 Reward -2898
# Epoch 881 Reward -2279
# Epoch 325 Reward -274
# Epoch 531 Reward -1362
# Epoch 3273 Reward -7056
# Epoch 3084 Reward -8370
# Epoch 2632 Reward -4696
# Epoch 514 Reward -706
# Epoch 2960 Reward -6347
# Epoch 1562 Reward -3140
# Epoch 1322 Reward -3818
# Epoch 543 Reward -1059
# Epoch 1535 Reward -2897
# Epoch 1148 Reward -1952
# Epoch 1171 Reward -2731
# Epoch 1343 Reward -2687
# Epoch 1357 Reward -2333
# Epoch 433 Reward -1750
# Epoch 598 Reward -1204
# Epoch 1555 Reward -3349
# Epoch 860 Reward -1700
# Epoch 46 Reward 185
# Epoch 216 Reward -427
# Epoch 205 Reward -352
# Epoch 264 Reward -240
# Epoch 259 Reward -730
# Epoch 1659 Reward -4155
# Epoch 301 Reward -835
# Epoch 187 Reward -370
# Epoch 503 Reward -1451
# Epoch 1002 Reward -1563
# Epoch 644 Reward -962
# Epoch 221 Reward -341
# Epoch 1193 Reward -2996
# Epoch 451 Reward -724
# Epoch 110 Reward -158
# Epoch 1129 Reward -3130
# Epoch 476 Reward -911
# Epoch 636 Reward -1890
# Epoch 878 Reward -1763
# Epoch 987 Reward -1854
# Epoch 420 Reward -1107
# Epoch 380 Reward -707
# Epoch 470 Reward -1220
# Epoch 46 Reward 113
# Epoch 233 Reward -749
# Epoch 301 Reward -1465
# Epoch 475 Reward -919
# Epoch 714 Reward -1878
# Epoch 70 Reward -55
# Epoch 3008 Reward -6404
# Epoch 1630 Reward -2695
# Epoch 1712 Reward -5072
# Epoch 559 Reward -1084
# Epoch 895 Reward -1123
# Epoch 157 Reward -268
# Epoch 149 Reward -107
# Epoch 504 Reward -1587
# Epoch 1367 Reward -2315
# Epoch 329 Reward -701
# Epoch 1000 Reward -3181
# Epoch 508 Reward -3823
# Epoch 194 Reward -746
# Epoch 159 Reward -288
# Epoch 1095 Reward -2709
# Epoch 5869 Reward -12361
# Epoch 781 Reward -2251
# Epoch 1481 Reward -2465
# Epoch 358 Reward -802
# Epoch 2634 Reward -5553
# Epoch 1173 Reward -1842
# Epoch 1498 Reward -5110
# Epoch 854 Reward -1091
# Epoch 231 Reward -207
# Epoch 1380 Reward -3525
# Epoch 428 Reward -773
# Epoch 1107 Reward -2685
# Epoch 3484 Reward -6331
# Epoch 692 Reward -1640
# Epoch 740 Reward -753
# Epoch 291 Reward -699
# Epoch 351 Reward -426
# Epoch 1285 Reward -1567
# Epoch 2300 Reward -4553
# Epoch 991 Reward -1291
# Epoch 2621 Reward -4064
# Epoch 1162 Reward -2101
# Epoch 1278 Reward -1551
# Epoch 666 Reward -921
# Epoch 267 Reward -180
# Epoch 1566 Reward -2235
# Epoch 2815 Reward -3529
# Epoch 98 Reward 25
# Epoch 408 Reward -879
# Epoch 507 Reward -1212
# Epoch 258 Reward -1017
# Epoch 801 Reward -2847
# Epoch 2217 Reward -2589
# Epoch 2328 Reward -3717
# Epoch 927 Reward -1848
# Epoch 1809 Reward -3180
# Epoch 1395 Reward -4431
# Epoch 412 Reward -2422
# Epoch 517 Reward -871
# Epoch 1500 Reward -2430
# Epoch 2785 Reward -7198
# Epoch 553 Reward -817
# Epoch 283 Reward -484
# Epoch 867 Reward -3876
# Epoch 1247 Reward -2186
# Epoch 1051 Reward -1405
# Epoch 3341 Reward -5963
# Epoch 3779 Reward -5879
# Epoch 1189 Reward -2740
# Epoch 388 Reward -526
# Epoch 1528 Reward -4006
# Epoch 269 Reward -560
# Epoch 381 Reward -1437
# Epoch 462 Reward -1806
# Epoch 4316 Reward -10574
# Epoch 6434 Reward -11000
# Epoch 1173 Reward -1158
# Epoch 10796 Reward -16145
# Epoch 4232 Reward -6629
# Epoch 3626 Reward -11018
# Epoch 3803 Reward -8090
# Epoch 4678 Reward -15571
# Epoch 5108 Reward -8234
# Epoch 2510 Reward -6473
# Epoch 993 Reward -1437
# Epoch 521 Reward -1307
# Epoch 6181 Reward -7588
# Epoch 780 Reward -1944
# Epoch 11139 Reward -14148
# Epoch 3726 Reward -4071
# Epoch 5128 Reward -7876
# Epoch 13019 Reward -17423
# Epoch 16761 Reward -25638
# Epoch 5589 Reward -7068
# Epoch 5019 Reward -7047
# Epoch 6851 Reward -10643
# Epoch 3666 Reward -5280
# Epoch 1147 Reward -2680
# Epoch 212 Reward -1007
# Epoch 12125 Reward -17348
# Epoch 1088 Reward -965
# Epoch 1212 Reward -2268
# Epoch 4855 Reward -8584
# Epoch 1836 Reward -2550
# Epoch 2260 Reward -3613
# Epoch 1794 Reward -2643
# Epoch 845 Reward -1604
# Epoch 5217 Reward -10071
# Epoch 449 Reward -515
# Epoch 1476 Reward -3144
# Epoch 592 Reward -2080
# Epoch 3345 Reward -6147
# Epoch 1326 Reward -2643
# Epoch 2139 Reward -4194
# Epoch 19794 Reward -27924
# Epoch 10357 Reward -14662
# Epoch 8232 Reward -11259
# Epoch 6408 Reward -9867
# Epoch 2530 Reward -3883
# Epoch 3930 Reward -4519
# Epoch 4243 Reward -7639
# Epoch 3407 Reward -4734
# Epoch 1804 Reward -4678
# Epoch 643 Reward -1888
# Epoch 3642 Reward -5976
# Epoch 402 Reward -846
# Epoch 493 Reward -1414
# Epoch 2480 Reward -4166
# Epoch 1384 Reward -3034
# Epoch 4669 Reward -9037
# Epoch 356 Reward -764
# Epoch 351 Reward -282
# Epoch 1260 Reward -2154
# Epoch 2376 Reward -3738
# Epoch 158 Reward -440
# Epoch 1229 Reward -2978
# Epoch 779 Reward -1934
# Epoch 472 Reward -1060
# Epoch 2202 Reward -2727
# Epoch 2720 Reward -2975
# Epoch 4942 Reward -6970
# Epoch 362 Reward -1751
# Epoch 2340 Reward -4935
# Epoch 553 Reward -403
# Epoch 4252 Reward -5218
# Epoch 1365 Reward -3609
# Epoch 745 Reward -1198
# Epoch 976 Reward -1726
# Epoch 2724 Reward -3843
# Epoch 7496 Reward -9641
# Epoch 1129 Reward -1834
# Epoch 1431 Reward -2244
# Epoch 787 Reward -799
# Epoch 2161 Reward -4036
# Epoch 1333 Reward -2596
# Epoch 909 Reward -948
# Epoch 226 Reward -670
# Epoch 2431 Reward -3217
# Epoch 198 Reward -1209
# Epoch 1280 Reward -1535
# Epoch 158 Reward -171
# Epoch 223 Reward -919
# Epoch 141 Reward -405
# Epoch 385 Reward -1450
# Epoch 2025 Reward -4440
# Epoch 284 Reward -980
# Epoch 890 Reward -2036
# Epoch 720 Reward -1794
# Epoch 3621 Reward -6180
# Epoch 2970 Reward -3882
# Epoch 6687 Reward -9291
# Epoch 62 Reward 159
# Epoch 812 Reward -1013
# Epoch 1735 Reward -2701
# Epoch 835 Reward -1180
# Epoch 1896 Reward -2520
# Epoch 1090 Reward -1768
# Epoch 181 Reward -211
# Epoch 114 Reward 117
# Epoch 791 Reward -992
# Epoch 562 Reward -619
# Epoch 678 Reward -1644
# Epoch 303 Reward -261
# Epoch 840 Reward -1356
# Epoch 485 Reward -2045
# Epoch 88 Reward -280
# Epoch 1594 Reward -3244
# Epoch 3750 Reward -8883
# Epoch 696 Reward -1437
# Epoch 1383 Reward -4221
# Epoch 2888 Reward -4133
# Epoch 4496 Reward -7046
# Epoch 3913 Reward -4708
# Epoch 1205 Reward -1451
# Epoch 2154 Reward -2490
# Epoch 1064 Reward -1292
# Epoch 2037 Reward -5595
# Epoch 1029 Reward -1041
# Epoch 1365 Reward -1656
# Epoch 796 Reward -1096
# Epoch 1351 Reward -3316
# Epoch 2534 Reward -4679
# Epoch 2946 Reward -5406
# Epoch 2415 Reward -4875
# Epoch 2558 Reward -4424
# Epoch 1249 Reward -2008
# Epoch 829 Reward -2218
# Epoch 223 Reward -64
# Epoch 5645 Reward -7250
# Epoch 829 Reward -904
# Epoch 1605 Reward -2661
# Epoch 3325 Reward -4129
# Epoch 1360 Reward -2164
# Epoch 974 Reward -1175
# Epoch 2258 Reward -5627
# Epoch 549 Reward -597
# Epoch 3487 Reward -7081
# Epoch 1350 Reward -1857
# Epoch 603 Reward -804
# Epoch 1469 Reward -4028
# Epoch 3031 Reward -4060
# Epoch 1969 Reward -5635
# Epoch 2488 Reward -4615
# Epoch 254 Reward -1526
# Epoch 1017 Reward -1965
# Epoch 2299 Reward -3787
# Epoch 525 Reward -546
# Epoch 515 Reward -1319
# Epoch 1445 Reward -2825
# Epoch 3570 Reward -5031
# Epoch 6199 Reward -8065
# Epoch 224 Reward -578
# Epoch 447 Reward -1063
# Epoch 1232 Reward -3386
# Epoch 5248 Reward -11893
# Epoch 9127 Reward -14575
# Epoch 1261 Reward -1705
# Epoch 3654 Reward -4665
# Epoch 774 Reward -957
# Epoch 1197 Reward -2037
# Epoch 433 Reward -1561
# Epoch 4699 Reward -7429
# Epoch 6804 Reward -8319
# Epoch 3828 Reward -7062
# Epoch 3360 Reward -4749
# Epoch 6094 Reward -8248
# Epoch 7688 Reward -10238
# Epoch 8121 Reward -10680
# Epoch 4303 Reward -5224
# Epoch 1863 Reward -4008
# Epoch 314 Reward -425
# Epoch 508 Reward -2176
# Epoch 3793 Reward -5704
# Epoch 479 Reward -347
# Epoch 741 Reward -1320
# Epoch 896 Reward -1196
# Epoch 877 Reward -871
# Epoch 1451 Reward -3335
# Epoch 3457 Reward -4891
# Epoch 2603 Reward -2966
# Epoch 1493 Reward -1712
# Epoch 715 Reward -1429
# Epoch 599 Reward -1412
# Epoch 677 Reward -1922
# Epoch 55 Reward 194
# Epoch 1371 Reward -1833
# Epoch 1150 Reward -2224
# Epoch 182 Reward -176
# Epoch 633 Reward -969
# Epoch 1294 Reward -3665
# Epoch 420 Reward -765
# Epoch 191 Reward -374
# Epoch 1935 Reward -3576
# Epoch 5127 Reward -9675
# Epoch 121 Reward -43
# Epoch 1123 Reward -3187
# Epoch 438 Reward -1044
# Epoch 882 Reward -3036
# Epoch 334 Reward -652
# Epoch 211 Reward -790
# Epoch 3520 Reward -6547
# Epoch 1660 Reward -3004
# Epoch 814 Reward -862
# Epoch 758 Reward -1841
# Epoch 923 Reward -917
# Epoch 3559 Reward -5560
# Epoch 2109 Reward -2868
# Epoch 348 Reward -1152
# Epoch 382 Reward -1609
# Epoch 1042 Reward -4159
# Epoch 5124 Reward -7656
# Epoch 2966 Reward -5957
# Epoch 545 Reward -2897
# Epoch 3236 Reward -5165
# Epoch 1983 Reward -3291
# Epoch 7805 Reward -14774
# Epoch 3029 Reward -7397
# Epoch 107 Reward -605
# Epoch 4535 Reward -10037
# Epoch 2587 Reward -4867
# Epoch 3998 Reward -16880
# Epoch 5373 Reward -10785
# Epoch 2477 Reward -4766
# Epoch 2549 Reward -3677
# Epoch 5301 Reward -9768
# Epoch 4209 Reward -5652
# Epoch 10953 Reward -16680
# Epoch 879 Reward -2646
# Epoch 3535 Reward -4465
# Epoch 1712 Reward -2876
# Epoch 4696 Reward -11242
# Epoch 669 Reward -2706
# Epoch 89 Reward -254
# Epoch 442 Reward -1210
# Epoch 1704 Reward -2598
# Epoch 2457 Reward -2820
# Epoch 3098 Reward -4712
# Epoch 468 Reward -336
# Epoch 294 Reward -1926
# Epoch 3819 Reward -4992
# Epoch 2785 Reward -4039
# Epoch 1275 Reward -1206
# Epoch 1444 Reward -2716
# Epoch 4563 Reward -20694
# Epoch 240 Reward -981
# Epoch 1059 Reward -2466
# Epoch 3133 Reward -6916
# Epoch 814 Reward -1474
# Epoch 686 Reward -1805
# Epoch 1498 Reward -5173
# Epoch 1143 Reward -2406
# Epoch 1771 Reward -2620
# Epoch 2014 Reward -4186
# Epoch 3637 Reward -5764
# Epoch 536 Reward -972
# Epoch 1141 Reward -1585
# Epoch 5138 Reward -7679
# Epoch 1654 Reward -2566
# Epoch 6062 Reward -8117
# Epoch 492 Reward -1323
# Epoch 369 Reward -705
# Epoch 3777 Reward -8217
# Epoch 2721 Reward -4290
# Epoch 6331 Reward -9214
# Epoch 1596 Reward -2319
# Epoch 1502 Reward -2810
# Epoch 564 Reward -621
# Epoch 115 Reward -595
# Epoch 1998 Reward -2424
# Epoch 1756 Reward -3334
# Epoch 951 Reward -1054
# Epoch 1340 Reward -2333
# Epoch 1813 Reward -3814
# Epoch 993 Reward -870
# Epoch 2339 Reward -4034
# Epoch 1668 Reward -2328
# Epoch 3486 Reward -5226
# Epoch 4944 Reward -12300
# Epoch 190 Reward -364
# Epoch 629 Reward -3287
# Epoch 704 Reward -3353
# Epoch 348 Reward -414
# Epoch 541 Reward -1453
# Epoch 562 Reward -1969
# Epoch 1251 Reward -3846
# Epoch 1393 Reward -2971
# Epoch 1181 Reward -2210
# Epoch 1856 Reward -5567
# Epoch 472 Reward -2455
# Epoch 1074 Reward -1689
# Epoch 1060 Reward -1126
# Epoch 1413 Reward -2892
# Epoch 2410 Reward -6319
# Epoch 2020 Reward -9484
# Epoch 70 Reward -136
# Epoch 159 Reward -1026
# Epoch 670 Reward -6235
# Epoch 248 Reward -1916
# Epoch 2325 Reward -10338
# Epoch 1678 Reward -8593
# Epoch 2996 Reward -5276
# Epoch 2837 Reward -3578
# Epoch 137 Reward -554
# Epoch 1040 Reward -2654
# Epoch 983 Reward -3002
# Epoch 790 Reward -1252
# Epoch 2539 Reward -7825
# Epoch 1835 Reward -5654
# Epoch 2368 Reward -7339
# Epoch 2915 Reward -9605
# Epoch 499 Reward -4093
# Epoch 1865 Reward -14405
# Epoch 4015 Reward -23179
# Epoch 238 Reward -403
# Epoch 5694 Reward -17703
# Epoch 2827 Reward -2956
# Epoch 1143 Reward -6735
# Epoch 902 Reward -6422
# Epoch 291 Reward -2427
# Epoch 785 Reward -6971
# Epoch 398 Reward -3524
# Epoch 1530 Reward -14718
# Epoch 2828 Reward -27392
# Epoch 84 Reward -474
# Epoch 581 Reward -5372
# Epoch 346 Reward -3022
# Epoch 498 Reward -4524
# Epoch 303 Reward -2682
# Epoch 678 Reward -6342
# Epoch 161 Reward -1280
# Epoch 1715 Reward -16424
# Epoch 4106 Reward -33305
# Epoch 620 Reward -4655
# Epoch 791 Reward -6698
# Epoch 1799 Reward -7859
# Epoch 7518 Reward -21867
# Epoch 8691 Reward -16129
# Epoch 11057 Reward -37493
# Epoch 24830 Reward -46361
# Epoch 2339 Reward -3926
# Epoch 2383 Reward -6265
# Epoch 1711 Reward -5296
# Epoch 2363 Reward -7496
# Epoch 2082 Reward -3093
# Epoch 7705 Reward -11434

# %%
# tensorflow와 그 안의 모델을 실행
with tf.Session() as sess:
    # 저장 객체 생성
    saver = tf.train.Saver()
    
    # 저장된 모델 로드
    saver.restore(sess, './model-1306635') 

    done = False
    obs = env.reset()
    total_reward = 0


    #상태가 최종 상태가 아닌 동안
    while not done:

        display.clear_output(wait=True)
        display.display(plt.gcf())
        env.render()

        # 전처리된 게임 화면 가져오기
        obs = env.render('dqn')

        # 게임 화면을 피드하고 각 작업에 대한 Q 값을 가져오기
        actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode: False})

        # 행동 가져오기
        action = np.argmax(actions, axis =-1)

        #행동을 수행하고 다음 상태인 next_obs로 이동하여 보상을 받는다.
        next_obs, reward, done, _ = env.step(action)
        total_reward += reward
        print("Episode Reward= ", total_reward)
        time.sleep(0.5)
# Out:
# o - - - - - - - - - - - - - - - - - o
# |   |       |           |           |
# |           | - |   |   | - | - |   |
# |   |               |   |           |
# | - |                       | - |   |
# |       |   |                       |
# |   |     4                 | - |   |
# |   |     4                 |       |
# |   | - | - | - |           | - |   |
# |                               | - |
# o - - - - - - - - - - - - - - - - - o
#
# Episode Reward=  -3961
